# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt

# Load images
img1 = cv.imread('myleft.jpeg', cv.IMREAD_GRAYSCALE)  # queryimage (left image)
img2 = cv.imread('myright.jpeg', cv.IMREAD_GRAYSCALE)  # trainimage (right image)

# Initialize SIFT detector
sift = cv.SIFT_create()

# Find keypoints and descriptors with SIFT
kp1, des1 = sift.detectAndCompute(img1, None)
kp2, des2 = sift.detectAndCompute(img2, None)

# FLANN parameters
FLANN_INDEX_KDTREE = 1
index_params = dict(algorithm=FLANN_INDEX_KDTREE, trees=5)
search_params = dict(checks=50)
flann = cv.FlannBasedMatcher(index_params, search_params)

# Perform knn matching
matches = flann.knnMatch(des1, des2, k=2)

# Ratio test as per Lowe's paper
pts1 = []
pts2 = []
for i, (m, n) in enumerate(matches):
    if m.distance < 0.8 * n.distance:
        pts2.append(kp2[m.trainIdx].pt)
        pts1.append(kp1[m.queryIdx].pt)

# Convert points to numpy arrays of integers
pts1 = np.int32(pts1)
pts2 = np.int32(pts2)

# Find Fundamental Matrix using RANSAC
F, mask = cv.findFundamentalMat(pts1, pts2, cv.FM_LMEDS)

# Select only inlier points
pts1 = pts1[mask.ravel() == 1]
pts2 = pts2[mask.ravel() == 1]

# Function to draw epilines and points on images
def drawlines(img1, img2, lines, pts1, pts2):
    '''Draw epilines and points on images'''
    r, c = img1.shape
    img1_color = cv.cvtColor(img1, cv.COLOR_GRAY2BGR)
    img2_color = cv.cvtColor(img2, cv.COLOR_GRAY2BGR)
    
    for r, pt1, pt2 in zip(lines, pts1, pts2):
        color = tuple(np.random.randint(0, 255, 3).tolist())
        x0, y0 = map(int, [0, -r[2]/r[1]])
        x1, y1 = map(int, [c, -(r[2] + r[0]*c)/r[1]])
        img1_color = cv.line(img1_color, (x0, y0), (x1, y1), color, 1)
        img1_color = cv.circle(img1_color, tuple(pt1), 5, color, -1)
        img2_color = cv.circle(img2_color, tuple(pt2), 5, color, -1)
    
    return img1_color, img2_color

# Compute epilines
lines1 = cv.computeCorrespondEpilines(pts2.reshape(-1, 1, 2), 2, F)
lines1 = lines1.reshape(-1, 3)
img5, img6 = drawlines(img1, img2, lines1, pts1, pts2)

lines2 = cv.computeCorrespondEpilines(pts1.reshape(-1, 1, 2), 1, F)
lines2 = lines2.reshape(-1, 3)
img3, img4 = drawlines(img2, img1, lines2, pts2, pts1)

# Display images with epilines
plt.subplot(121), plt.imshow(img5)
plt.subplot(122), plt.imshow(img3)
plt.show()

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt

# Load images
img1 = cv.imread('myleft.jpeg', cv.IMREAD_GRAYSCALE)  # queryimage (left image)
img2 = cv.imread('myright.jpeg', cv.IMREAD_GRAYSCALE)  # trainimage (right image)

# Initialize SIFT detector
sift = cv.SIFT_create()

# Find keypoints and descriptors with SIFT
kp1, des1 = sift.detectAndCompute(img1, None)
kp2, des2 = sift.detectAndCompute(img2, None)

# FLANN parameters
FLANN_INDEX_KDTREE = 1
index_params = dict(algorithm=FLANN_INDEX_KDTREE, trees=5)
search_params = dict(checks=50)
flann = cv.FlannBasedMatcher(index_params, search_params)

# Perform knn matching
matches = flann.knnMatch(des1, des2, k=2)

# Ratio test as per Lowe's paper
good_matches = []
for m, n in matches:
    if m.distance < 0.8 * n.distance:
        good_matches.append(m)

# Extract matched keypoints
pts1 = np.float32([kp1[m.queryIdx].pt for m in good_matches]).reshape(-1, 1, 2)
pts2 = np.float32([kp2[m.trainIdx].pt for m in good_matches]).reshape(-1, 1, 2)

# Find Fundamental Matrix using RANSAC
F, mask = cv.findFundamentalMat(pts1, pts2, cv.FM_RANSAC)

# Select only inlier points
pts1 = pts1[mask.ravel() == 1]
pts2 = pts2[mask.ravel() == 1]

# Print coordinates and distance of each point
for i in range(len(pts1)):
    print(f"Point {i+1}:")
    print(f"  Image 1 coordinate: {pts1[i]}")
    print(f"  Image 2 coordinate: {pts2[i]}")
    print(f"  Distance: {np.linalg.norm(pts1[i] - pts2[i])}")
    print()

# Find epilines and draw them
def drawlines(img1, img2, lines, pts1, pts2):
    # Draw epilines on img1 for points in img2
    img1_color = cv.cvtColor(img1, cv.COLOR_GRAY2BGR)
    img2_color = cv.cvtColor(img2, cv.COLOR_GRAY2BGR)
    
    for r, pt1, pt2 in zip(lines, pts1, pts2):
        color = tuple(np.random.randint(0, 255, 3).tolist())
        x0, y0 = map(int, [0, -r[2]/r[1]])
        x1, y1 = map(int, [img1.shape[1], -(r[2] + r[0]*img1.shape[1])/r[1]])
        img1_color = cv.line(img1_color, (x0, y0), (x1, y1), color, 1)
        img1_color = cv.circle(img1_color, tuple(pt1[0]), 5, color, -1)
        img2_color = cv.circle(img2_color, tuple(pt2[0]), 5, color, -1)
    
    return img1_color, img2_color

# Compute epilines
lines1 = cv.computeCorrespondEpilines(pts2, 2, F)
lines1 = lines1.reshape(-1, 3)
img5, img6 = drawlines(img1, img2, lines1, pts1, pts2)

lines2 = cv.computeCorrespondEpilines(pts1, 1, F)
lines2 = lines2.reshape(-1, 3)
img3, img4 = drawlines(img2, img1, lines2, pts2, pts1)

# Display images with epilines
plt.subplot(121), plt.imshow(img5)
plt.title('Epilines in Image 1 corresponding to points in Image 2'), plt.xticks([]), plt.yticks([])
plt.subplot(122), plt.imshow(img3)
plt.title('Epilines in Image 2 corresponding to points in Image 1'), plt.xticks([]), plt.yticks([])
plt.show()
# Out:
# Point 1:
#   Image 1 coordinate: [[  17.043703 1133.9727  ]]
#   Image 2 coordinate: [[ 64.34758 875.92   ]]
#   Distance: 262.3525085449219
#
# Point 2:
#   Image 1 coordinate: [[ 21.00583 708.128  ]]
#   Image 2 coordinate: [[448.23816 682.0749 ]]
#   Distance: 428.0259704589844
#
# Point 3:
#   Image 1 coordinate: [[ 29.269909 850.5011  ]]
#   Image 2 coordinate: [[436.288  782.3586]]
#   Distance: 412.682861328125
#
# Point 4:
#   Image 1 coordinate: [[ 31.782362 853.5471  ]]
#   Image 2 coordinate: [[437.35733 785.2229 ]]
#   Distance: 411.2897644042969
#
# Point 5:
#   Image 1 coordinate: [[ 33.82127 777.7964 ]]
#   Image 2 coordinate: [[445.8956 731.4498]]
#   Distance: 414.6724853515625
#
# Point 6:
#   Image 1 coordinate: [[ 34.44683 468.85422]]
#   Image 2 coordinate: [[444.03412 527.0851 ]]
#   Distance: 413.7059020996094
#
# Point 7:
#   Image 1 coordinate: [[ 36.555553 834.40753 ]]
#   Image 2 coordinate: [[443.65234 772.2925 ]]
#   Distance: 411.8083190917969
#
# Point 8:
#   Image 1 coordinate: [[ 39.200745 833.9571  ]]
#   Image 2 coordinate: [[443.65234 772.2925 ]]
#   Distance: 409.12542724609375
#
# Point 9:
#   Image 1 coordinate: [[ 40.149612 776.80817 ]]
#   Image 2 coordinate: [[448.96005 731.7224 ]]
#   Distance: 411.2890625
#
# Point 10:
#   Image 1 coordinate: [[ 50.59746 783.5488 ]]
#   Image 2 coordinate: [[454.34814 738.46936]]
#   Distance: 406.2594909667969
#
# Point 11:
#   Image 1 coordinate: [[ 54.972794 807.30115 ]]
#   Image 2 coordinate: [[454.4033  756.48865]]
#   Distance: 402.64947509765625
#
# Point 12:
#   Image 1 coordinate: [[ 62.23763 817.8271 ]]
#   Image 2 coordinate: [[459.37848 765.96234]]
#   Distance: 400.5131530761719
#
# Point 13:
#   Image 1 coordinate: [[ 65.62994 785.54944]]
#   Image 2 coordinate: [[462.99725 742.9132 ]]
#   Distance: 399.64813232421875
#
# Point 14:
#   Image 1 coordinate: [[ 66.414215 847.74066 ]]
#   Image 2 coordinate: [[456.45837 789.13153]]
#   Distance: 394.4229736328125
#
# Point 15:
#   Image 1 coordinate: [[ 68.6915  843.69446]]
#   Image 2 coordinate: [[458.55972 786.8232 ]]
#   Distance: 393.994384765625
#
# Point 16:
#   Image 1 coordinate: [[ 82.36286 842.61163]]
#   Image 2 coordinate: [[466.13898 788.87744]]
#   Distance: 387.5196228027344
#
# Point 17:
#   Image 1 coordinate: [[ 116.82312 1093.0056 ]]
#   Image 2 coordinate: [[ 64.34758 875.92   ]]
#   Distance: 223.33798217773438
#
# Point 18:
#   Image 1 coordinate: [[ 158.24231 1058.5502 ]]
#   Image 2 coordinate: [[ 62.865593 862.8952  ]]
#   Distance: 217.66392517089844
#
# Point 19:
#   Image 1 coordinate: [[ 171.04219 1077.3601 ]]
#   Image 2 coordinate: [[ 37.128967 870.91986 ]]
#   Distance: 246.06976318359375
#
# Point 20:
#   Image 1 coordinate: [[187.3093  829.16364]]
#   Image 2 coordinate: [[529.1885 804.2104]]
#   Distance: 342.78863525390625
#
# Point 21:
#   Image 1 coordinate: [[192.49913 788.10175]]
#   Image 2 coordinate: [[535.657  771.6286]]
#   Distance: 343.5530090332031
#
# Point 22:
#   Image 1 coordinate: [[194.3531  827.68884]]
#   Image 2 coordinate: [[534.09375 805.5814 ]]
#   Distance: 340.45916748046875
#
# Point 23:
#   Image 1 coordinate: [[198.00731 486.90033]]
#   Image 2 coordinate: [[566.1851  528.21906]]
#   Distance: 370.4890441894531
#
# Point 24:
#   Image 1 coordinate: [[202.13606 827.4748 ]]
#   Image 2 coordinate: [[539.61224 807.323  ]]
#   Distance: 338.07733154296875
#
# Point 25:
#   Image 1 coordinate: [[203.12956 811.52356]]
#   Image 2 coordinate: [[543.36664 795.15546]]
#   Distance: 340.63055419921875
#
# Point 26:
#   Image 1 coordinate: [[204.22998 811.6557 ]]
#   Image 2 coordinate: [[543.36664 795.15546]]
#   Distance: 339.5378112792969
#
# Point 27:
#   Image 1 coordinate: [[204.44312 804.4962 ]]
#   Image 2 coordinate: [[546.2602 789.7503]]
#   Distance: 342.135009765625
#
# Point 28:
#   Image 1 coordinate: [[206.339   815.16766]]
#   Image 2 coordinate: [[544.19714 798.40173]]
#   Distance: 338.2738952636719
#
# Point 29:
#   Image 1 coordinate: [[206.42888 827.0396 ]]
#   Image 2 coordinate: [[544.7593  808.44763]]
#   Distance: 338.8408203125
#
# Point 30:
#   Image 1 coordinate: [[217.51064 808.995  ]]
#   Image 2 coordinate: [[557.2862  797.30225]]
#   Distance: 339.9766845703125
#
# Point 31:
#   Image 1 coordinate: [[ 218.06952 1045.1075 ]]
#   Image 2 coordinate: [[ 99.51329 880.95056]]
#   Distance: 202.49220275878906
#
# Point 32:
#   Image 1 coordinate: [[219.30748 773.67017]]
#   Image 2 coordinate: [[557.1317 767.3317]]
#   Distance: 337.8836975097656
#
# Point 33:
#   Image 1 coordinate: [[223.85114 807.9161 ]]
#   Image 2 coordinate: [[557.2862  797.30225]]
#   Distance: 333.60394287109375
#
# Point 34:
#   Image 1 coordinate: [[224.5436 814.9193]]
#   Image 2 coordinate: [[557.0694 803.4352]]
#   Distance: 332.72406005859375
#
# Point 35:
#   Image 1 coordinate: [[269.10336 947.4704 ]]
#   Image 2 coordinate: [[709.27014 991.47406]]
#   Distance: 442.36083984375
#
# Point 36:
#   Image 1 coordinate: [[ 283.97052 1036.1852 ]]
#   Image 2 coordinate: [[ 37.128967 870.91986 ]]
#   Distance: 297.057861328125
#
# Point 37:
#   Image 1 coordinate: [[429.81454 751.2176 ]]
#   Image 2 coordinate: [[760.2719  813.03845]]
#   Distance: 336.19024658203125
#
# Point 38:
#   Image 1 coordinate: [[429.81454 751.2176 ]]
#   Image 2 coordinate: [[760.2719  813.03845]]
#   Distance: 336.19024658203125
#
# Point 39:
#   Image 1 coordinate: [[433.83298 748.6673 ]]
#   Image 2 coordinate: [[764.86365 811.899  ]]
#   Distance: 337.0156555175781
#
# Point 40:
#   Image 1 coordinate: [[438.17078 745.6706 ]]
#   Image 2 coordinate: [[769.9096 810.1952]]
#   Distance: 337.9557189941406
#
# Point 41:
#   Image 1 coordinate: [[438.48282 751.505  ]]
#   Image 2 coordinate: [[768.0236 815.8302]]
#   Distance: 335.7601318359375
#
# Point 42:
#   Image 1 coordinate: [[438.48282 751.505  ]]
#   Image 2 coordinate: [[768.0236 815.8302]]
#   Distance: 335.7601318359375
#
# Point 43:
#   Image 1 coordinate: [[443.62094 133.98224]]
#   Image 2 coordinate: [[809.5641  168.12836]]
#   Distance: 367.53277587890625
#
# Point 44:
#   Image 1 coordinate: [[463.10056 750.9633 ]]
#   Image 2 coordinate: [[791.5203  823.78296]]
#   Distance: 336.3959655761719
#
# Point 45:
#   Image 1 coordinate: [[468.75598 747.7491 ]]
#   Image 2 coordinate: [[796.0259  821.83344]]
#   Distance: 335.5504150390625
#
# Point 46:
#   Image 1 coordinate: [[477.1953  751.78674]]
#   Image 2 coordinate: [[804.657  829.4039]]
#   Distance: 336.5346374511719
#
# Point 47:
#   Image 1 coordinate: [[495.66742 745.0982 ]]
#   Image 2 coordinate: [[826.75616 829.2183 ]]
#   Distance: 341.6078796386719
#
# Point 48:
#   Image 1 coordinate: [[567.01636 717.91907]]
#   Image 2 coordinate: [[909.92505 822.7522 ]]
#   Distance: 358.575439453125
#
# Point 49:
#   Image 1 coordinate: [[571.89307 723.91534]]
#   Image 2 coordinate: [[916.7974 831.9869]]
#   Distance: 361.439453125
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[6], line 69
#      67 lines1 = cv.computeCorrespondEpilines(pts2, 2, F)
#      68 lines1 = lines1.reshape(-1, 3)
# ---> 69 img5, img6 = drawlines(img1, img2, lines1, pts1, pts2)
#      71 lines2 = cv.computeCorrespondEpilines(pts1, 1, F)
#      72 lines2 = lines2.reshape(-1, 3)
#
# Cell In[6], line 61, in drawlines(img1, img2, lines, pts1, pts2)
#      59     x1, y1 = map(int, [img1.shape[1], -(r[2] + r[0]*img1.shape[1])/r[1]])
#      60     img1_color = cv.line(img1_color, (x0, y0), (x1, y1), color, 1)
# ---> 61     img1_color = cv.circle(img1_color, tuple(pt1[0]), 5, color, -1)
#      62     img2_color = cv.circle(img2_color, tuple(pt2[0]), 5, color, -1)
#      64 return img1_color, img2_color
#
# error: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'circle'
# > Overload resolution failed:
# >  - Can't parse 'center'. Sequence item with index 0 has a wrong type
# >  - Can't parse 'center'. Sequence item with index 0 has a wrong type

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt

# Load images
img1 = cv.imread('myleft.jpeg', cv.IMREAD_GRAYSCALE)  # queryimage (left image)
img2 = cv.imread('myright.jpeg', cv.IMREAD_GRAYSCALE)  # trainimage (right image)

# Initialize SIFT detector
sift = cv.SIFT_create()

# Find keypoints and descriptors with SIFT
kp1, des1 = sift.detectAndCompute(img1, None)
kp2, des2 = sift.detectAndCompute(img2, None)

# FLANN parameters
FLANN_INDEX_KDTREE = 1
index_params = dict(algorithm=FLANN_INDEX_KDTREE, trees=5)
search_params = dict(checks=50)
flann = cv.FlannBasedMatcher(index_params, search_params)

# Perform knn matching
matches = flann.knnMatch(des1, des2, k=2)

# Ratio test as per Lowe's paper
pts1 = []
pts2 = []
for i, (m, n) in enumerate(matches):
    if m.distance < 0.8 * n.distance:
        pts2.append(kp2[m.trainIdx].pt)
        pts1.append(kp1[m.queryIdx].pt)

# Convert points to numpy arrays of integers
pts1 = np.int32(pts1)
pts2 = np.int32(pts2)

# Find Fundamental Matrix using RANSAC
F, mask = cv.findFundamentalMat(pts1, pts2, cv.FM_LMEDS)

# Select only inlier points
pts1 = pts1[mask.ravel() == 1]
pts2 = pts2[mask.ravel() == 1]

# Function to draw epilines and points on images
def drawlines(img1, img2, lines, pts1, pts2):
    '''Draw epilines and points on images'''
    r, c = img1.shape
    img1_color = cv.cvtColor(img1, cv.COLOR_GRAY2BGR)
    img2_color = cv.cvtColor(img2, cv.COLOR_GRAY2BGR)
    
    for i, (r, pt1, pt2) in enumerate(zip(lines, pts1, pts2)):
        color = tuple(np.random.randint(0, 255, 3).tolist())
        x0, y0 = map(int, [0, -r[2]/r[1]])
        x1, y1 = map(int, [c, -(r[2] + r[0]*c)/r[1]])
        img1_color = cv.line(img1_color, (x0, y0), (x1, y1), color, 1)
        
        # Calculate distance (this is a placeholder, you need to implement actual distance calculation)
        distance = np.linalg.norm(pt1 - pt2)  # Euclidean distance between corresponding points
        
        # Label points with numbers and distances
        cv.putText(img1_color, f'{i+1}: {distance:.2f}', tuple(pt1), cv.FONT_HERSHEY_SIMPLEX, 0.5, color, 1)
        cv.putText(img2_color, f'{i+1}: {distance:.2f}', tuple(pt2), cv.FONT_HERSHEY_SIMPLEX, 0.5, color, 1)
        
        img1_color = cv.circle(img1_color, tuple(pt1), 5, color, -1)
        img2_color = cv.circle(img2_color, tuple(pt2), 5, color, -1)
        
        # Print coordinates
        print(f"Point {i+1}: Left image coordinates: {pt1}, Right image coordinates: {pt2}")
    
    return img1_color, img2_color

# Compute epilines
lines1 = cv.computeCorrespondEpilines(pts2.reshape(-1, 1, 2), 2, F)
lines1 = lines1.reshape(-1, 3)
img5, img6 = drawlines(img1, img2, lines1, pts1, pts2)

lines2 = cv.computeCorrespondEpilines(pts1.reshape(-1, 1, 2), 1, F)
lines2 = lines2.reshape(-1, 3)
img3, img4 = drawlines(img2, img1, lines2, pts2, pts1)

# Display images with epilines
plt.figure(figsize=(20,10))
plt.subplot(121), plt.imshow(cv.cvtColor(img5, cv.COLOR_BGR2RGB))
plt.title('Left Image with Epilines and Labeled Points')
plt.subplot(122), plt.imshow(cv.cvtColor(img3, cv.COLOR_BGR2RGB))
plt.title('Right Image with Epilines and Labeled Points')
plt.show()
# Out:
# Point 1: Left image coordinates: [   3 1180], Right image coordinates: [  31 1188]
# Point 2: Left image coordinates: [   5 1091], Right image coordinates: [ 649 1052]
# Point 3: Left image coordinates: [  8 703], Right image coordinates: [ 462 1196]
# Point 4: Left image coordinates: [ 10 812], Right image coordinates: [466 788]
# Point 5: Left image coordinates: [ 13 486], Right image coordinates: [453 524]
# Point 6: Left image coordinates: [ 15 564], Right image coordinates: [764 839]
# Point 7: Left image coordinates: [ 16 412], Right image coordinates: [431 781]
# Point 8: Left image coordinates: [  17 1133], Right image coordinates: [ 64 875]
# Point 9: Left image coordinates: [ 18 847], Right image coordinates: [428 654]
# Point 10: Left image coordinates: [  18 1195], Right image coordinates: [ 64 875]
# Point 11: Left image coordinates: [  19 1214], Right image coordinates: [ 85 873]
# Point 12: Left image coordinates: [ 19 811], Right image coordinates: [ 298 1226]
# Point 13: Left image coordinates: [ 21 708], Right image coordinates: [448 682]
# Point 14: Left image coordinates: [  23 1175], Right image coordinates: [ 64 875]
# Point 15: Left image coordinates: [  25 1182], Right image coordinates: [704 884]
# Point 16: Left image coordinates: [  25 1182], Right image coordinates: [704 884]
# Point 17: Left image coordinates: [  27 1165], Right image coordinates: [  31 1188]
# Point 18: Left image coordinates: [  29 1175], Right image coordinates: [ 95 886]
# Point 19: Left image coordinates: [ 29 850], Right image coordinates: [436 782]
# Point 20: Left image coordinates: [ 29 773], Right image coordinates: [578 578]
# Point 21: Left image coordinates: [  31 1248], Right image coordinates: [ 49 895]
# Point 22: Left image coordinates: [ 31 853], Right image coordinates: [437 785]
# Point 23: Left image coordinates: [ 33 777], Right image coordinates: [445 731]
# Point 24: Left image coordinates: [  33 1260], Right image coordinates: [ 45 880]
# Point 25: Left image coordinates: [ 34 468], Right image coordinates: [444 527]
# Point 26: Left image coordinates: [ 35 404], Right image coordinates: [420 747]
# Point 27: Left image coordinates: [ 36 834], Right image coordinates: [443 772]
# Point 28: Left image coordinates: [  37 1136], Right image coordinates: [ 64 875]
# Point 29: Left image coordinates: [ 39 833], Right image coordinates: [443 772]
# Point 30: Left image coordinates: [  39 1211], Right image coordinates: [ 64 875]
# Point 31: Left image coordinates: [  40 1023], Right image coordinates: [ 679 1019]
# Point 32: Left image coordinates: [ 40 776], Right image coordinates: [448 731]
# Point 33: Left image coordinates: [  49 1117], Right image coordinates: [ 85 873]
# Point 34: Left image coordinates: [ 50 783], Right image coordinates: [454 738]
# Point 35: Left image coordinates: [ 54 807], Right image coordinates: [454 756]
# Point 36: Left image coordinates: [  55 1146], Right image coordinates: [  31 1188]
# Point 37: Left image coordinates: [  57 1136], Right image coordinates: [ 64 875]
# Point 38: Left image coordinates: [ 62 817], Right image coordinates: [459 765]
# Point 39: Left image coordinates: [ 65 785], Right image coordinates: [462 742]
# Point 40: Left image coordinates: [  66 1188], Right image coordinates: [ 45 880]
# Point 41: Left image coordinates: [ 66 847], Right image coordinates: [456 789]
# Point 42: Left image coordinates: [ 68 960], Right image coordinates: [ 607 1209]
# Point 43: Left image coordinates: [ 68 843], Right image coordinates: [458 786]
# Point 44: Left image coordinates: [  74 1019], Right image coordinates: [ 339 1193]
# Point 45: Left image coordinates: [  75 1154], Right image coordinates: [ 64 875]
# Point 46: Left image coordinates: [ 77 804], Right image coordinates: [465 758]
# Point 47: Left image coordinates: [  79 1139], Right image coordinates: [ 64 875]
# Point 48: Left image coordinates: [ 79 558], Right image coordinates: [196 986]
# Point 49: Left image coordinates: [  80 1032], Right image coordinates: [738 958]
# Point 50: Left image coordinates: [ 82 842], Right image coordinates: [466 788]
# Point 51: Left image coordinates: [ 90 989], Right image coordinates: [709 991]
# Point 52: Left image coordinates: [  91 1270], Right image coordinates: [918 917]
# Point 53: Left image coordinates: [ 94 262], Right image coordinates: [485 448]
# Point 54: Left image coordinates: [ 97 531], Right image coordinates: [166 762]
# Point 55: Left image coordinates: [ 100 1195], Right image coordinates: [ 469 1099]
# Point 56: Left image coordinates: [101 676], Right image coordinates: [446 868]
# Point 57: Left image coordinates: [ 104 1218], Right image coordinates: [ 24 862]
# Point 58: Left image coordinates: [ 105 1161], Right image coordinates: [ 85 873]
# Point 59: Left image coordinates: [107 711], Right image coordinates: [293 750]
# Point 60: Left image coordinates: [ 109 1005], Right image coordinates: [ 313 1054]
# Point 61: Left image coordinates: [111 744], Right image coordinates: [475 436]
# Point 62: Left image coordinates: [ 111 1039], Right image coordinates: [ 360 1073]
# Point 63: Left image coordinates: [112 711], Right image coordinates: [879 234]
# Point 64: Left image coordinates: [116 862], Right image coordinates: [504 728]
# Point 65: Left image coordinates: [ 116 1093], Right image coordinates: [ 64 875]
# Point 66: Left image coordinates: [ 117 1102], Right image coordinates: [852 799]
# Point 67: Left image coordinates: [ 118 1028], Right image coordinates: [ 560 1142]
# Point 68: Left image coordinates: [120 532], Right image coordinates: [866 180]
# Point 69: Left image coordinates: [120 951], Right image coordinates: [ 65 976]
# Point 70: Left image coordinates: [ 121 1254], Right image coordinates: [ 49 895]
# Point 71: Left image coordinates: [121 593], Right image coordinates: [ 46 493]
# Point 72: Left image coordinates: [ 121 1080], Right image coordinates: [ 64 875]
# Point 73: Left image coordinates: [ 127 1068], Right image coordinates: [ 64 875]
# Point 74: Left image coordinates: [128 391], Right image coordinates: [344 194]
# Point 75: Left image coordinates: [ 130 1231], Right image coordinates: [ 246 1240]
# Point 76: Left image coordinates: [130 364], Right image coordinates: [479 637]
# Point 77: Left image coordinates: [130 359], Right image coordinates: [410 614]
# Point 78: Left image coordinates: [138 490], Right image coordinates: [410 614]
# Point 79: Left image coordinates: [138 495], Right image coordinates: [504 627]
# Point 80: Left image coordinates: [ 138 1101], Right image coordinates: [351 829]
# Point 81: Left image coordinates: [ 140 1238], Right image coordinates: [704 884]
# Point 82: Left image coordinates: [ 146 1071], Right image coordinates: [ 64 875]
# Point 83: Left image coordinates: [147 643], Right image coordinates: [334 839]
# Point 84: Left image coordinates: [149 223], Right image coordinates: [485 448]
# Point 85: Left image coordinates: [153 341], Right image coordinates: [799 302]
# Point 86: Left image coordinates: [ 161 1031], Right image coordinates: [900 925]
# Point 87: Left image coordinates: [ 167 1090], Right image coordinates: [ 37 870]
# Point 88: Left image coordinates: [ 168 1072], Right image coordinates: [ 85 873]
# Point 89: Left image coordinates: [169 984], Right image coordinates: [ 395 1035]
# Point 90: Left image coordinates: [ 171 1077], Right image coordinates: [ 37 870]
# Point 91: Left image coordinates: [171 982], Right image coordinates: [ 395 1035]
# Point 92: Left image coordinates: [173 320], Right image coordinates: [438 662]
# Point 93: Left image coordinates: [174 926], Right image coordinates: [249 849]
# Point 94: Left image coordinates: [ 175 1220], Right image coordinates: [ 49 895]
# Point 95: Left image coordinates: [ 176 1226], Right image coordinates: [ 74 884]
# Point 96: Left image coordinates: [ 176 1226], Right image coordinates: [ 74 884]
# Point 97: Left image coordinates: [ 176 1174], Right image coordinates: [ 49 895]
# Point 98: Left image coordinates: [ 179 1011], Right image coordinates: [ 538 1144]
# Point 99: Left image coordinates: [ 183 1000], Right image coordinates: [675 939]
# Point 100: Left image coordinates: [187 829], Right image coordinates: [529 804]
# Point 101: Left image coordinates: [192 788], Right image coordinates: [535 771]
# Point 102: Left image coordinates: [ 193 1058], Right image coordinates: [ 60 896]
# Point 103: Left image coordinates: [ 193 1058], Right image coordinates: [ 60 896]
# Point 104: Left image coordinates: [194 827], Right image coordinates: [534 805]
# Point 105: Left image coordinates: [196 106], Right image coordinates: [588 218]
# Point 106: Left image coordinates: [198 486], Right image coordinates: [566 528]
# Point 107: Left image coordinates: [198 479], Right image coordinates: [571 780]
# Point 108: Left image coordinates: [198 697], Right image coordinates: [740 296]
# Point 109: Left image coordinates: [ 200 1215], Right image coordinates: [466 524]
# Point 110: Left image coordinates: [ 202 1187], Right image coordinates: [ 49 895]
# Point 111: Left image coordinates: [202 827], Right image coordinates: [539 807]
# Point 112: Left image coordinates: [202 962], Right image coordinates: [ 643 1079]
# Point 113: Left image coordinates: [203 811], Right image coordinates: [543 795]
# Point 114: Left image coordinates: [ 203 1130], Right image coordinates: [ 49 895]
# Point 115: Left image coordinates: [ 203 1225], Right image coordinates: [503 871]
# Point 116: Left image coordinates: [204 824], Right image coordinates: [470 790]
# Point 117: Left image coordinates: [204 811], Right image coordinates: [543 795]
# Point 118: Left image coordinates: [204 804], Right image coordinates: [546 789]
# Point 119: Left image coordinates: [205 960], Right image coordinates: [ 643 1079]
# Point 120: Left image coordinates: [ 205 1175], Right image coordinates: [ 90 906]
# Point 121: Left image coordinates: [206 815], Right image coordinates: [544 798]
# Point 122: Left image coordinates: [206 827], Right image coordinates: [544 808]
# Point 123: Left image coordinates: [207 559], Right image coordinates: [426 413]
# Point 124: Left image coordinates: [ 210 1083], Right image coordinates: [ 85 873]
# Point 125: Left image coordinates: [ 212 1152], Right image coordinates: [ 24 862]
# Point 126: Left image coordinates: [213 599], Right image coordinates: [568 621]
# Point 127: Left image coordinates: [213 974], Right image coordinates: [181 958]
# Point 128: Left image coordinates: [214 593], Right image coordinates: [569 616]
# Point 129: Left image coordinates: [ 214 1056], Right image coordinates: [ 85 873]
# Point 130: Left image coordinates: [216 551], Right image coordinates: [ 432 1182]
# Point 131: Left image coordinates: [216 360], Right image coordinates: [574 757]
# Point 132: Left image coordinates: [217 544], Right image coordinates: [432 388]
# Point 133: Left image coordinates: [217 808], Right image coordinates: [557 797]
# Point 134: Left image coordinates: [218 539], Right image coordinates: [432 388]
# Point 135: Left image coordinates: [219 773], Right image coordinates: [557 767]
# Point 136: Left image coordinates: [222 512], Right image coordinates: [ 517 1115]
# Point 137: Left image coordinates: [223 807], Right image coordinates: [557 797]
# Point 138: Left image coordinates: [224 581], Right image coordinates: [626 194]
# Point 139: Left image coordinates: [224 814], Right image coordinates: [557 803]
# Point 140: Left image coordinates: [ 225 1232], Right image coordinates: [ 16 859]
# Point 141: Left image coordinates: [226 857], Right image coordinates: [565 842]
# Point 142: Left image coordinates: [226 821], Right image coordinates: [557 808]
# Point 143: Left image coordinates: [226 532], Right image coordinates: [459 765]
# Point 144: Left image coordinates: [228 706], Right image coordinates: [625 952]
# Point 145: Left image coordinates: [230 129], Right image coordinates: [497 507]
# Point 146: Left image coordinates: [ 231 1103], Right image coordinates: [ 28 849]
# Point 147: Left image coordinates: [232 466], Right image coordinates: [419 394]
# Point 148: Left image coordinates: [236 912], Right image coordinates: [332 828]
# Point 149: Left image coordinates: [239 598], Right image coordinates: [625 948]
# Point 150: Left image coordinates: [ 245 1026], Right image coordinates: [ 86 868]
# Point 151: Left image coordinates: [245 376], Right image coordinates: [426 522]
# Point 152: Left image coordinates: [245 178], Right image coordinates: [660 260]
# Point 153: Left image coordinates: [ 247 1188], Right image coordinates: [362 863]
# Point 154: Left image coordinates: [ 250 1148], Right image coordinates: [ 49 895]
# Point 155: Left image coordinates: [ 257 1051], Right image coordinates: [ 85 873]
# Point 156: Left image coordinates: [ 260 1145], Right image coordinates: [ 45 880]
# Point 157: Left image coordinates: [266 992], Right image coordinates: [ 340 1021]
# Point 158: Left image coordinates: [ 270 1165], Right image coordinates: [ 49 895]
# Point 159: Left image coordinates: [ 272 1169], Right image coordinates: [ 58 901]
# Point 160: Left image coordinates: [ 277 1106], Right image coordinates: [ 74 884]
# Point 161: Left image coordinates: [ 282 1055], Right image coordinates: [151 831]
# Point 162: Left image coordinates: [ 283 1036], Right image coordinates: [ 37 870]
# Point 163: Left image coordinates: [290 955], Right image coordinates: [ 410 1186]
# Point 164: Left image coordinates: [296 913], Right image coordinates: [ 435 1076]
# Point 165: Left image coordinates: [297 932], Right image coordinates: [ 558 1080]
# Point 166: Left image coordinates: [ 298 1114], Right image coordinates: [ 49 895]
# Point 167: Left image coordinates: [ 304 1068], Right image coordinates: [ 85 873]
# Point 168: Left image coordinates: [ 311 1068], Right image coordinates: [704 884]
# Point 169: Left image coordinates: [ 312 1086], Right image coordinates: [704 884]
# Point 170: Left image coordinates: [ 312 1125], Right image coordinates: [704 884]
# Point 171: Left image coordinates: [314 749], Right image coordinates: [880 285]
# Point 172: Left image coordinates: [316 128], Right image coordinates: [426 413]
# Point 173: Left image coordinates: [321 931], Right image coordinates: [682 917]
# Point 174: Left image coordinates: [324 941], Right image coordinates: [ 317 1096]
# Point 175: Left image coordinates: [325 385], Right image coordinates: [755 208]
# Point 176: Left image coordinates: [ 331 1184], Right image coordinates: [575 663]
# Point 177: Left image coordinates: [ 331 1184], Right image coordinates: [ 49 895]
# Point 178: Left image coordinates: [ 333 1132], Right image coordinates: [704 884]
# Point 179: Left image coordinates: [ 337 1271], Right image coordinates: [ 368 1047]
# Point 180: Left image coordinates: [337 652], Right image coordinates: [576 587]
# Point 181: Left image coordinates: [ 338 1162], Right image coordinates: [ 68 915]
# Point 182: Left image coordinates: [342 664], Right image coordinates: [722 783]
# Point 183: Left image coordinates: [343 668], Right image coordinates: [722 783]
# Point 184: Left image coordinates: [343 675], Right image coordinates: [722 783]
# Point 185: Left image coordinates: [ 345 1186], Right image coordinates: [ 63 929]
# Point 186: Left image coordinates: [355 985], Right image coordinates: [421 359]
# Point 187: Left image coordinates: [355 315], Right image coordinates: [780 490]
# Point 188: Left image coordinates: [359 994], Right image coordinates: [ 234 1251]
# Point 189: Left image coordinates: [ 360 1152], Right image coordinates: [ 81 919]
# Point 190: Left image coordinates: [361 165], Right image coordinates: [706 228]
# Point 191: Left image coordinates: [366 160], Right image coordinates: [764 213]
# Point 192: Left image coordinates: [ 368 1137], Right image coordinates: [ 91 916]
# Point 193: Left image coordinates: [ 369 1143], Right image coordinates: [ 45 880]
# Point 194: Left image coordinates: [ 369 1115], Right image coordinates: [ 53 917]
# Point 195: Left image coordinates: [371 934], Right image coordinates: [710 937]
# Point 196: Left image coordinates: [373 529], Right image coordinates: [491 356]
# Point 197: Left image coordinates: [ 375 1165], Right image coordinates: [ 49 895]
# Point 198: Left image coordinates: [ 384 1096], Right image coordinates: [781 882]
# Point 199: Left image coordinates: [ 386 1223], Right image coordinates: [ 617 1230]
# Point 200: Left image coordinates: [388 740], Right image coordinates: [823 293]
# Point 201: Left image coordinates: [ 389 1169], Right image coordinates: [ 85 938]
# Point 202: Left image coordinates: [393 864], Right image coordinates: [458 562]
# Point 203: Left image coordinates: [396 749], Right image coordinates: [ 524 1050]
# Point 204: Left image coordinates: [397 117], Right image coordinates: [626 194]
# Point 205: Left image coordinates: [400 585], Right image coordinates: [725 568]
# Point 206: Left image coordinates: [400 572], Right image coordinates: [725 568]
# Point 207: Left image coordinates: [ 402 1058], Right image coordinates: [440 566]
# Point 208: Left image coordinates: [403 258], Right image coordinates: [103 578]
# Point 209: Left image coordinates: [406 649], Right image coordinates: [589 551]
# Point 210: Left image coordinates: [409 259], Right image coordinates: [430 605]
# Point 211: Left image coordinates: [412 640], Right image coordinates: [449 784]
# Point 212: Left image coordinates: [414 135], Right image coordinates: [778 180]
# Point 213: Left image coordinates: [ 418 1080], Right image coordinates: [458 562]
# Point 214: Left image coordinates: [422 875], Right image coordinates: [ 361 1259]
# Point 215: Left image coordinates: [429 751], Right image coordinates: [760 813]
# Point 216: Left image coordinates: [429 751], Right image coordinates: [760 813]
# Point 217: Left image coordinates: [ 431 1165], Right image coordinates: [161 806]
# Point 218: Left image coordinates: [433 748], Right image coordinates: [764 811]
# Point 219: Left image coordinates: [435 893], Right image coordinates: [788 959]
# Point 220: Left image coordinates: [438 745], Right image coordinates: [769 810]
# Point 221: Left image coordinates: [438 751], Right image coordinates: [768 815]
# Point 222: Left image coordinates: [438 751], Right image coordinates: [768 815]
# Point 223: Left image coordinates: [443 133], Right image coordinates: [809 168]
# Point 224: Left image coordinates: [458 158], Right image coordinates: [ 46 493]
# Point 225: Left image coordinates: [459 761], Right image coordinates: [783 834]
# Point 226: Left image coordinates: [463 750], Right image coordinates: [791 823]
# Point 227: Left image coordinates: [463 759], Right image coordinates: [788 831]
# Point 228: Left image coordinates: [464 860], Right image coordinates: [690 835]
# Point 229: Left image coordinates: [ 468 1112], Right image coordinates: [ 215 1051]
# Point 230: Left image coordinates: [468 747], Right image coordinates: [796 821]
# Point 231: Left image coordinates: [468 575], Right image coordinates: [869 495]
# Point 232: Left image coordinates: [469 579], Right image coordinates: [869 495]
# Point 233: Left image coordinates: [477 751], Right image coordinates: [804 829]
# Point 234: Left image coordinates: [ 479 1013], Right image coordinates: [ 645 1087]
# Point 235: Left image coordinates: [485 750], Right image coordinates: [814 830]
# Point 236: Left image coordinates: [487 990], Right image coordinates: [251 898]
# Point 237: Left image coordinates: [495 745], Right image coordinates: [826 829]
# Point 238: Left image coordinates: [502 175], Right image coordinates: [918 183]
# Point 239: Left image coordinates: [504   2], Right image coordinates: [855  10]
# Point 240: Left image coordinates: [505 177], Right image coordinates: [922 185]
# Point 241: Left image coordinates: [ 507 1052], Right image coordinates: [ 235 1066]
# Point 242: Left image coordinates: [ 510 1180], Right image coordinates: [247 999]
# Point 243: Left image coordinates: [511 233], Right image coordinates: [589 551]
# Point 244: Left image coordinates: [511 854], Right image coordinates: [531 894]
# Point 245: Left image coordinates: [ 517 1085], Right image coordinates: [ 580 1059]
# Point 246: Left image coordinates: [526 855], Right image coordinates: [563 923]
# Point 247: Left image coordinates: [ 530 1208], Right image coordinates: [ 322 1069]
# Point 248: Left image coordinates: [ 532 1207], Right image coordinates: [ 301 1014]
# Point 249: Left image coordinates: [536  11], Right image coordinates: [755  34]
# Point 250: Left image coordinates: [ 550 1219], Right image coordinates: [ 707 1040]
# Point 251: Left image coordinates: [ 551 1258], Right image coordinates: [ 404 1215]
# Point 252: Left image coordinates: [ 556 1120], Right image coordinates: [ 459 1250]
# Point 253: Left image coordinates: [ 556 1120], Right image coordinates: [ 297 1071]
# Point 254: Left image coordinates: [ 565 1145], Right image coordinates: [ 298 1222]
# Point 255: Left image coordinates: [567 717], Right image coordinates: [909 822]
# Point 256: Left image coordinates: [572 730], Right image coordinates: [918 841]
# Point 257: Left image coordinates: [ 579 1264], Right image coordinates: [ 512 1131]
# Point 258: Left image coordinates: [ 581 1152], Right image coordinates: [ 284 1105]
# Point 259: Left image coordinates: [ 589 1266], Right image coordinates: [307 821]
# Point 260: Left image coordinates: [591 750], Right image coordinates: [372 842]
# Point 261: Left image coordinates: [591 368], Right image coordinates: [459 765]
# Point 262: Left image coordinates: [ 594 1120], Right image coordinates: [356 992]
# Point 263: Left image coordinates: [ 613 1098], Right image coordinates: [ 340 1021]
# Point 264: Left image coordinates: [ 614 1063], Right image coordinates: [ 651 1111]
# Point 265: Left image coordinates: [ 619 1050], Right image coordinates: [347 931]
# Point 266: Left image coordinates: [ 620 1107], Right image coordinates: [ 308 1086]
# Point 267: Left image coordinates: [620 757], Right image coordinates: [ 515 1213]
# Point 268: Left image coordinates: [ 628 1168], Right image coordinates: [ 548 1129]
# Point 269: Left image coordinates: [ 630 1054], Right image coordinates: [ 577 1267]
# Point 270: Left image coordinates: [651 155], Right image coordinates: [474 339]
# Point 271: Left image coordinates: [ 652 1254], Right image coordinates: [ 438 1043]
# Point 272: Left image coordinates: [654 831], Right image coordinates: [335 830]
# Point 273: Left image coordinates: [ 660 1030], Right image coordinates: [518 882]
# Point 274: Left image coordinates: [ 663 1122], Right image coordinates: [ 661 1125]
# Point 275: Left image coordinates: [673 481], Right image coordinates: [630 300]
# Point 276: Left image coordinates: [ 674 1244], Right image coordinates: [500 815]
# Point 277: Left image coordinates: [ 680 1215], Right image coordinates: [181 958]
# Point 278: Left image coordinates: [ 684 1125], Right image coordinates: [ 699 1025]
# Point 279: Left image coordinates: [ 685 1130], Right image coordinates: [ 675 1052]
# Point 280: Left image coordinates: [693 787], Right image coordinates: [886 926]
# Point 281: Left image coordinates: [ 696 1217], Right image coordinates: [306 850]
# Point 282: Left image coordinates: [702 630], Right image coordinates: [562 662]
# Point 283: Left image coordinates: [702 193], Right image coordinates: [337 343]
# Point 284: Left image coordinates: [707 938], Right image coordinates: [419 853]
# Point 285: Left image coordinates: [709 238], Right image coordinates: [229 272]
# Point 286: Left image coordinates: [ 720 1091], Right image coordinates: [ 228 1076]
# Point 287: Left image coordinates: [722  35], Right image coordinates: [145 650]
# Point 288: Left image coordinates: [724 802], Right image coordinates: [790 949]
# Point 289: Left image coordinates: [ 726 1141], Right image coordinates: [ 206 1115]
# Point 290: Left image coordinates: [ 734 1036], Right image coordinates: [431 781]
# Point 291: Left image coordinates: [735  28], Right image coordinates: [145 650]
# Point 292: Left image coordinates: [737 219], Right image coordinates: [566 528]
# Point 293: Left image coordinates: [749 959], Right image coordinates: [ 210 1064]
# Point 294: Left image coordinates: [758 642], Right image coordinates: [898 267]
# Point 295: Left image coordinates: [ 758 1030], Right image coordinates: [ 308 1086]
# Point 296: Left image coordinates: [760 840], Right image coordinates: [669 975]
# Point 297: Left image coordinates: [761 240], Right image coordinates: [249 793]
# Point 298: Left image coordinates: [ 763 1105], Right image coordinates: [279 816]
# Point 299: Left image coordinates: [ 765 1165], Right image coordinates: [459 765]
# Point 300: Left image coordinates: [779   4], Right image coordinates: [871   6]
# Point 301: Left image coordinates: [780 951], Right image coordinates: [166 762]
# Point 302: Left image coordinates: [784 905], Right image coordinates: [ 598 1001]
# Point 303: Left image coordinates: [786 910], Right image coordinates: [853 846]
# Point 304: Left image coordinates: [ 786 1058], Right image coordinates: [365 986]
# Point 305: Left image coordinates: [789  86], Right image coordinates: [839 197]
# Point 306: Left image coordinates: [813 194], Right image coordinates: [446 411]
# Point 307: Left image coordinates: [ 826 1161], Right image coordinates: [395 826]
# Point 308: Left image coordinates: [851 952], Right image coordinates: [715 929]
# Point 309: Left image coordinates: [853  53], Right image coordinates: [726 547]
# Point 310: Left image coordinates: [ 862 1054], Right image coordinates: [ 481 1109]
# Point 311: Left image coordinates: [868 962], Right image coordinates: [ 410 1158]
# Point 312: Left image coordinates: [ 869 1049], Right image coordinates: [192 945]
# Point 313: Left image coordinates: [869 227], Right image coordinates: [495 744]
# Point 314: Left image coordinates: [873 164], Right image coordinates: [837  86]
# Point 315: Left image coordinates: [875 938], Right image coordinates: [193 960]
# Point 316: Left image coordinates: [879 551], Right image coordinates: [630 300]
# Point 317: Left image coordinates: [879 551], Right image coordinates: [630 300]
# Point 318: Left image coordinates: [893 379], Right image coordinates: [573 828]
# Point 319: Left image coordinates: [901 214], Right image coordinates: [589 551]
# Point 320: Left image coordinates: [906 983], Right image coordinates: [ 413 1079]
# Point 321: Left image coordinates: [912 157], Right image coordinates: [593 315]
# Point 322: Left image coordinates: [ 932 1024], Right image coordinates: [ 535 1155]
# Point 323: Left image coordinates: [941  79], Right image coordinates: [576 672]
# Point 324: Left image coordinates: [ 947 1145], Right image coordinates: [749 931]
# Point 1: Left image coordinates: [  31 1188], Right image coordinates: [   3 1180]
# Point 2: Left image coordinates: [ 649 1052], Right image coordinates: [   5 1091]
# Point 3: Left image coordinates: [ 462 1196], Right image coordinates: [  8 703]
# Point 4: Left image coordinates: [466 788], Right image coordinates: [ 10 812]
# Point 5: Left image coordinates: [453 524], Right image coordinates: [ 13 486]
# Point 6: Left image coordinates: [764 839], Right image coordinates: [ 15 564]
# Point 7: Left image coordinates: [431 781], Right image coordinates: [ 16 412]
# Point 8: Left image coordinates: [ 64 875], Right image coordinates: [  17 1133]
# Point 9: Left image coordinates: [428 654], Right image coordinates: [ 18 847]
# Point 10: Left image coordinates: [ 64 875], Right image coordinates: [  18 1195]
# Point 11: Left image coordinates: [ 85 873], Right image coordinates: [  19 1214]
# Point 12: Left image coordinates: [ 298 1226], Right image coordinates: [ 19 811]
# Point 13: Left image coordinates: [448 682], Right image coordinates: [ 21 708]
# Point 14: Left image coordinates: [ 64 875], Right image coordinates: [  23 1175]
# Point 15: Left image coordinates: [704 884], Right image coordinates: [  25 1182]
# Point 16: Left image coordinates: [704 884], Right image coordinates: [  25 1182]
# Point 17: Left image coordinates: [  31 1188], Right image coordinates: [  27 1165]
# Point 18: Left image coordinates: [ 95 886], Right image coordinates: [  29 1175]
# Point 19: Left image coordinates: [436 782], Right image coordinates: [ 29 850]
# Point 20: Left image coordinates: [578 578], Right image coordinates: [ 29 773]
# Point 21: Left image coordinates: [ 49 895], Right image coordinates: [  31 1248]
# Point 22: Left image coordinates: [437 785], Right image coordinates: [ 31 853]
# Point 23: Left image coordinates: [445 731], Right image coordinates: [ 33 777]
# Point 24: Left image coordinates: [ 45 880], Right image coordinates: [  33 1260]
# Point 25: Left image coordinates: [444 527], Right image coordinates: [ 34 468]
# Point 26: Left image coordinates: [420 747], Right image coordinates: [ 35 404]
# Point 27: Left image coordinates: [443 772], Right image coordinates: [ 36 834]
# Point 28: Left image coordinates: [ 64 875], Right image coordinates: [  37 1136]
# Point 29: Left image coordinates: [443 772], Right image coordinates: [ 39 833]
# Point 30: Left image coordinates: [ 64 875], Right image coordinates: [  39 1211]
# Point 31: Left image coordinates: [ 679 1019], Right image coordinates: [  40 1023]
# Point 32: Left image coordinates: [448 731], Right image coordinates: [ 40 776]
# Point 33: Left image coordinates: [ 85 873], Right image coordinates: [  49 1117]
# Point 34: Left image coordinates: [454 738], Right image coordinates: [ 50 783]
# Point 35: Left image coordinates: [454 756], Right image coordinates: [ 54 807]
# Point 36: Left image coordinates: [  31 1188], Right image coordinates: [  55 1146]
# Point 37: Left image coordinates: [ 64 875], Right image coordinates: [  57 1136]
# Point 38: Left image coordinates: [459 765], Right image coordinates: [ 62 817]
# Point 39: Left image coordinates: [462 742], Right image coordinates: [ 65 785]
# Point 40: Left image coordinates: [ 45 880], Right image coordinates: [  66 1188]
# Point 41: Left image coordinates: [456 789], Right image coordinates: [ 66 847]
# Point 42: Left image coordinates: [ 607 1209], Right image coordinates: [ 68 960]
# Point 43: Left image coordinates: [458 786], Right image coordinates: [ 68 843]
# Point 44: Left image coordinates: [ 339 1193], Right image coordinates: [  74 1019]
# Point 45: Left image coordinates: [ 64 875], Right image coordinates: [  75 1154]
# Point 46: Left image coordinates: [465 758], Right image coordinates: [ 77 804]
# Point 47: Left image coordinates: [ 64 875], Right image coordinates: [  79 1139]
# Point 48: Left image coordinates: [196 986], Right image coordinates: [ 79 558]
# Point 49: Left image coordinates: [738 958], Right image coordinates: [  80 1032]
# Point 50: Left image coordinates: [466 788], Right image coordinates: [ 82 842]
# Point 51: Left image coordinates: [709 991], Right image coordinates: [ 90 989]
# Point 52: Left image coordinates: [918 917], Right image coordinates: [  91 1270]
# Point 53: Left image coordinates: [485 448], Right image coordinates: [ 94 262]
# Point 54: Left image coordinates: [166 762], Right image coordinates: [ 97 531]
# Point 55: Left image coordinates: [ 469 1099], Right image coordinates: [ 100 1195]
# Point 56: Left image coordinates: [446 868], Right image coordinates: [101 676]
# Point 57: Left image coordinates: [ 24 862], Right image coordinates: [ 104 1218]
# Point 58: Left image coordinates: [ 85 873], Right image coordinates: [ 105 1161]
# Point 59: Left image coordinates: [293 750], Right image coordinates: [107 711]
# Point 60: Left image coordinates: [ 313 1054], Right image coordinates: [ 109 1005]
# Point 61: Left image coordinates: [475 436], Right image coordinates: [111 744]
# Point 62: Left image coordinates: [ 360 1073], Right image coordinates: [ 111 1039]
# Point 63: Left image coordinates: [879 234], Right image coordinates: [112 711]
# Point 64: Left image coordinates: [504 728], Right image coordinates: [116 862]
# Point 65: Left image coordinates: [ 64 875], Right image coordinates: [ 116 1093]
# Point 66: Left image coordinates: [852 799], Right image coordinates: [ 117 1102]
# Point 67: Left image coordinates: [ 560 1142], Right image coordinates: [ 118 1028]
# Point 68: Left image coordinates: [866 180], Right image coordinates: [120 532]
# Point 69: Left image coordinates: [ 65 976], Right image coordinates: [120 951]
# Point 70: Left image coordinates: [ 49 895], Right image coordinates: [ 121 1254]
# Point 71: Left image coordinates: [ 46 493], Right image coordinates: [121 593]
# Point 72: Left image coordinates: [ 64 875], Right image coordinates: [ 121 1080]
# Point 73: Left image coordinates: [ 64 875], Right image coordinates: [ 127 1068]
# Point 74: Left image coordinates: [344 194], Right image coordinates: [128 391]
# Point 75: Left image coordinates: [ 246 1240], Right image coordinates: [ 130 1231]
# Point 76: Left image coordinates: [479 637], Right image coordinates: [130 364]
# Point 77: Left image coordinates: [410 614], Right image coordinates: [130 359]
# Point 78: Left image coordinates: [410 614], Right image coordinates: [138 490]
# Point 79: Left image coordinates: [504 627], Right image coordinates: [138 495]
# Point 80: Left image coordinates: [351 829], Right image coordinates: [ 138 1101]
# Point 81: Left image coordinates: [704 884], Right image coordinates: [ 140 1238]
# Point 82: Left image coordinates: [ 64 875], Right image coordinates: [ 146 1071]
# Point 83: Left image coordinates: [334 839], Right image coordinates: [147 643]
# Point 84: Left image coordinates: [485 448], Right image coordinates: [149 223]
# Point 85: Left image coordinates: [799 302], Right image coordinates: [153 341]
# Point 86: Left image coordinates: [900 925], Right image coordinates: [ 161 1031]
# Point 87: Left image coordinates: [ 37 870], Right image coordinates: [ 167 1090]
# Point 88: Left image coordinates: [ 85 873], Right image coordinates: [ 168 1072]
# Point 89: Left image coordinates: [ 395 1035], Right image coordinates: [169 984]
# Point 90: Left image coordinates: [ 37 870], Right image coordinates: [ 171 1077]
# Point 91: Left image coordinates: [ 395 1035], Right image coordinates: [171 982]
# Point 92: Left image coordinates: [438 662], Right image coordinates: [173 320]
# Point 93: Left image coordinates: [249 849], Right image coordinates: [174 926]
# Point 94: Left image coordinates: [ 49 895], Right image coordinates: [ 175 1220]
# Point 95: Left image coordinates: [ 74 884], Right image coordinates: [ 176 1226]
# Point 96: Left image coordinates: [ 74 884], Right image coordinates: [ 176 1226]
# Point 97: Left image coordinates: [ 49 895], Right image coordinates: [ 176 1174]
# Point 98: Left image coordinates: [ 538 1144], Right image coordinates: [ 179 1011]
# Point 99: Left image coordinates: [675 939], Right image coordinates: [ 183 1000]
# Point 100: Left image coordinates: [529 804], Right image coordinates: [187 829]
# Point 101: Left image coordinates: [535 771], Right image coordinates: [192 788]
# Point 102: Left image coordinates: [ 60 896], Right image coordinates: [ 193 1058]
# Point 103: Left image coordinates: [ 60 896], Right image coordinates: [ 193 1058]
# Point 104: Left image coordinates: [534 805], Right image coordinates: [194 827]
# Point 105: Left image coordinates: [588 218], Right image coordinates: [196 106]
# Point 106: Left image coordinates: [566 528], Right image coordinates: [198 486]
# Point 107: Left image coordinates: [571 780], Right image coordinates: [198 479]
# Point 108: Left image coordinates: [740 296], Right image coordinates: [198 697]
# Point 109: Left image coordinates: [466 524], Right image coordinates: [ 200 1215]
# Point 110: Left image coordinates: [ 49 895], Right image coordinates: [ 202 1187]
# Point 111: Left image coordinates: [539 807], Right image coordinates: [202 827]
# Point 112: Left image coordinates: [ 643 1079], Right image coordinates: [202 962]
# Point 113: Left image coordinates: [543 795], Right image coordinates: [203 811]
# Point 114: Left image coordinates: [ 49 895], Right image coordinates: [ 203 1130]
# Point 115: Left image coordinates: [503 871], Right image coordinates: [ 203 1225]
# Point 116: Left image coordinates: [470 790], Right image coordinates: [204 824]
# Point 117: Left image coordinates: [543 795], Right image coordinates: [204 811]
# Point 118: Left image coordinates: [546 789], Right image coordinates: [204 804]
# Point 119: Left image coordinates: [ 643 1079], Right image coordinates: [205 960]
# Point 120: Left image coordinates: [ 90 906], Right image coordinates: [ 205 1175]
# Point 121: Left image coordinates: [544 798], Right image coordinates: [206 815]
# Point 122: Left image coordinates: [544 808], Right image coordinates: [206 827]
# Point 123: Left image coordinates: [426 413], Right image coordinates: [207 559]
# Point 124: Left image coordinates: [ 85 873], Right image coordinates: [ 210 1083]
# Point 125: Left image coordinates: [ 24 862], Right image coordinates: [ 212 1152]
# Point 126: Left image coordinates: [568 621], Right image coordinates: [213 599]
# Point 127: Left image coordinates: [181 958], Right image coordinates: [213 974]
# Point 128: Left image coordinates: [569 616], Right image coordinates: [214 593]
# Point 129: Left image coordinates: [ 85 873], Right image coordinates: [ 214 1056]
# Point 130: Left image coordinates: [ 432 1182], Right image coordinates: [216 551]
# Point 131: Left image coordinates: [574 757], Right image coordinates: [216 360]
# Point 132: Left image coordinates: [432 388], Right image coordinates: [217 544]
# Point 133: Left image coordinates: [557 797], Right image coordinates: [217 808]
# Point 134: Left image coordinates: [432 388], Right image coordinates: [218 539]
# Point 135: Left image coordinates: [557 767], Right image coordinates: [219 773]
# Point 136: Left image coordinates: [ 517 1115], Right image coordinates: [222 512]
# Point 137: Left image coordinates: [557 797], Right image coordinates: [223 807]
# Point 138: Left image coordinates: [626 194], Right image coordinates: [224 581]
# Point 139: Left image coordinates: [557 803], Right image coordinates: [224 814]
# Point 140: Left image coordinates: [ 16 859], Right image coordinates: [ 225 1232]
# Point 141: Left image coordinates: [565 842], Right image coordinates: [226 857]
# Point 142: Left image coordinates: [557 808], Right image coordinates: [226 821]
# Point 143: Left image coordinates: [459 765], Right image coordinates: [226 532]
# Point 144: Left image coordinates: [625 952], Right image coordinates: [228 706]
# Point 145: Left image coordinates: [497 507], Right image coordinates: [230 129]
# Point 146: Left image coordinates: [ 28 849], Right image coordinates: [ 231 1103]
# Point 147: Left image coordinates: [419 394], Right image coordinates: [232 466]
# Point 148: Left image coordinates: [332 828], Right image coordinates: [236 912]
# Point 149: Left image coordinates: [625 948], Right image coordinates: [239 598]
# Point 150: Left image coordinates: [ 86 868], Right image coordinates: [ 245 1026]
# Point 151: Left image coordinates: [426 522], Right image coordinates: [245 376]
# Point 152: Left image coordinates: [660 260], Right image coordinates: [245 178]
# Point 153: Left image coordinates: [362 863], Right image coordinates: [ 247 1188]
# Point 154: Left image coordinates: [ 49 895], Right image coordinates: [ 250 1148]
# Point 155: Left image coordinates: [ 85 873], Right image coordinates: [ 257 1051]
# Point 156: Left image coordinates: [ 45 880], Right image coordinates: [ 260 1145]
# Point 157: Left image coordinates: [ 340 1021], Right image coordinates: [266 992]
# Point 158: Left image coordinates: [ 49 895], Right image coordinates: [ 270 1165]
# Point 159: Left image coordinates: [ 58 901], Right image coordinates: [ 272 1169]
# Point 160: Left image coordinates: [ 74 884], Right image coordinates: [ 277 1106]
# Point 161: Left image coordinates: [151 831], Right image coordinates: [ 282 1055]
# Point 162: Left image coordinates: [ 37 870], Right image coordinates: [ 283 1036]
# Point 163: Left image coordinates: [ 410 1186], Right image coordinates: [290 955]
# Point 164: Left image coordinates: [ 435 1076], Right image coordinates: [296 913]
# Point 165: Left image coordinates: [ 558 1080], Right image coordinates: [297 932]
# Point 166: Left image coordinates: [ 49 895], Right image coordinates: [ 298 1114]
# Point 167: Left image coordinates: [ 85 873], Right image coordinates: [ 304 1068]
# Point 168: Left image coordinates: [704 884], Right image coordinates: [ 311 1068]
# Point 169: Left image coordinates: [704 884], Right image coordinates: [ 312 1086]
# Point 170: Left image coordinates: [704 884], Right image coordinates: [ 312 1125]
# Point 171: Left image coordinates: [880 285], Right image coordinates: [314 749]
# Point 172: Left image coordinates: [426 413], Right image coordinates: [316 128]
# Point 173: Left image coordinates: [682 917], Right image coordinates: [321 931]
# Point 174: Left image coordinates: [ 317 1096], Right image coordinates: [324 941]
# Point 175: Left image coordinates: [755 208], Right image coordinates: [325 385]
# Point 176: Left image coordinates: [575 663], Right image coordinates: [ 331 1184]
# Point 177: Left image coordinates: [ 49 895], Right image coordinates: [ 331 1184]
# Point 178: Left image coordinates: [704 884], Right image coordinates: [ 333 1132]
# Point 179: Left image coordinates: [ 368 1047], Right image coordinates: [ 337 1271]
# Point 180: Left image coordinates: [576 587], Right image coordinates: [337 652]
# Point 181: Left image coordinates: [ 68 915], Right image coordinates: [ 338 1162]
# Point 182: Left image coordinates: [722 783], Right image coordinates: [342 664]
# Point 183: Left image coordinates: [722 783], Right image coordinates: [343 668]
# Point 184: Left image coordinates: [722 783], Right image coordinates: [343 675]
# Point 185: Left image coordinates: [ 63 929], Right image coordinates: [ 345 1186]
# Point 186: Left image coordinates: [421 359], Right image coordinates: [355 985]
# Point 187: Left image coordinates: [780 490], Right image coordinates: [355 315]
# Point 188: Left image coordinates: [ 234 1251], Right image coordinates: [359 994]
# Point 189: Left image coordinates: [ 81 919], Right image coordinates: [ 360 1152]
# Point 190: Left image coordinates: [706 228], Right image coordinates: [361 165]
# Point 191: Left image coordinates: [764 213], Right image coordinates: [366 160]
# Point 192: Left image coordinates: [ 91 916], Right image coordinates: [ 368 1137]
# Point 193: Left image coordinates: [ 45 880], Right image coordinates: [ 369 1143]
# Point 194: Left image coordinates: [ 53 917], Right image coordinates: [ 369 1115]
# Point 195: Left image coordinates: [710 937], Right image coordinates: [371 934]
# Point 196: Left image coordinates: [491 356], Right image coordinates: [373 529]
# Point 197: Left image coordinates: [ 49 895], Right image coordinates: [ 375 1165]
# Point 198: Left image coordinates: [781 882], Right image coordinates: [ 384 1096]
# Point 199: Left image coordinates: [ 617 1230], Right image coordinates: [ 386 1223]
# Point 200: Left image coordinates: [823 293], Right image coordinates: [388 740]
# Point 201: Left image coordinates: [ 85 938], Right image coordinates: [ 389 1169]
# Point 202: Left image coordinates: [458 562], Right image coordinates: [393 864]
# Point 203: Left image coordinates: [ 524 1050], Right image coordinates: [396 749]
# Point 204: Left image coordinates: [626 194], Right image coordinates: [397 117]
# Point 205: Left image coordinates: [725 568], Right image coordinates: [400 585]
# Point 206: Left image coordinates: [725 568], Right image coordinates: [400 572]
# Point 207: Left image coordinates: [440 566], Right image coordinates: [ 402 1058]
# Point 208: Left image coordinates: [103 578], Right image coordinates: [403 258]
# Point 209: Left image coordinates: [589 551], Right image coordinates: [406 649]
# Point 210: Left image coordinates: [430 605], Right image coordinates: [409 259]
# Point 211: Left image coordinates: [449 784], Right image coordinates: [412 640]
# Point 212: Left image coordinates: [778 180], Right image coordinates: [414 135]
# Point 213: Left image coordinates: [458 562], Right image coordinates: [ 418 1080]
# Point 214: Left image coordinates: [ 361 1259], Right image coordinates: [422 875]
# Point 215: Left image coordinates: [760 813], Right image coordinates: [429 751]
# Point 216: Left image coordinates: [760 813], Right image coordinates: [429 751]
# Point 217: Left image coordinates: [161 806], Right image coordinates: [ 431 1165]
# Point 218: Left image coordinates: [764 811], Right image coordinates: [433 748]
# Point 219: Left image coordinates: [788 959], Right image coordinates: [435 893]
# Point 220: Left image coordinates: [769 810], Right image coordinates: [438 745]
# Point 221: Left image coordinates: [768 815], Right image coordinates: [438 751]
# Point 222: Left image coordinates: [768 815], Right image coordinates: [438 751]
# Point 223: Left image coordinates: [809 168], Right image coordinates: [443 133]
# Point 224: Left image coordinates: [ 46 493], Right image coordinates: [458 158]
# Point 225: Left image coordinates: [783 834], Right image coordinates: [459 761]
# Point 226: Left image coordinates: [791 823], Right image coordinates: [463 750]
# Point 227: Left image coordinates: [788 831], Right image coordinates: [463 759]
# Point 228: Left image coordinates: [690 835], Right image coordinates: [464 860]
# Point 229: Left image coordinates: [ 215 1051], Right image coordinates: [ 468 1112]
# Point 230: Left image coordinates: [796 821], Right image coordinates: [468 747]
# Point 231: Left image coordinates: [869 495], Right image coordinates: [468 575]
# Point 232: Left image coordinates: [869 495], Right image coordinates: [469 579]
# Point 233: Left image coordinates: [804 829], Right image coordinates: [477 751]
# Point 234: Left image coordinates: [ 645 1087], Right image coordinates: [ 479 1013]
# Point 235: Left image coordinates: [814 830], Right image coordinates: [485 750]
# Point 236: Left image coordinates: [251 898], Right image coordinates: [487 990]
# Point 237: Left image coordinates: [826 829], Right image coordinates: [495 745]
# Point 238: Left image coordinates: [918 183], Right image coordinates: [502 175]
# Point 239: Left image coordinates: [855  10], Right image coordinates: [504   2]
# Point 240: Left image coordinates: [922 185], Right image coordinates: [505 177]
# Point 241: Left image coordinates: [ 235 1066], Right image coordinates: [ 507 1052]
# Point 242: Left image coordinates: [247 999], Right image coordinates: [ 510 1180]
# Point 243: Left image coordinates: [589 551], Right image coordinates: [511 233]
# Point 244: Left image coordinates: [531 894], Right image coordinates: [511 854]
# Point 245: Left image coordinates: [ 580 1059], Right image coordinates: [ 517 1085]
# Point 246: Left image coordinates: [563 923], Right image coordinates: [526 855]
# Point 247: Left image coordinates: [ 322 1069], Right image coordinates: [ 530 1208]
# Point 248: Left image coordinates: [ 301 1014], Right image coordinates: [ 532 1207]
# Point 249: Left image coordinates: [755  34], Right image coordinates: [536  11]
# Point 250: Left image coordinates: [ 707 1040], Right image coordinates: [ 550 1219]
# Point 251: Left image coordinates: [ 404 1215], Right image coordinates: [ 551 1258]
# Point 252: Left image coordinates: [ 459 1250], Right image coordinates: [ 556 1120]
# Point 253: Left image coordinates: [ 297 1071], Right image coordinates: [ 556 1120]
# Point 254: Left image coordinates: [ 298 1222], Right image coordinates: [ 565 1145]
# Point 255: Left image coordinates: [909 822], Right image coordinates: [567 717]
# Point 256: Left image coordinates: [918 841], Right image coordinates: [572 730]
# Point 257: Left image coordinates: [ 512 1131], Right image coordinates: [ 579 1264]
# Point 258: Left image coordinates: [ 284 1105], Right image coordinates: [ 581 1152]
# Point 259: Left image coordinates: [307 821], Right image coordinates: [ 589 1266]
# Point 260: Left image coordinates: [372 842], Right image coordinates: [591 750]
# Point 261: Left image coordinates: [459 765], Right image coordinates: [591 368]
# Point 262: Left image coordinates: [356 992], Right image coordinates: [ 594 1120]
# Point 263: Left image coordinates: [ 340 1021], Right image coordinates: [ 613 1098]
# Point 264: Left image coordinates: [ 651 1111], Right image coordinates: [ 614 1063]
# Point 265: Left image coordinates: [347 931], Right image coordinates: [ 619 1050]
# Point 266: Left image coordinates: [ 308 1086], Right image coordinates: [ 620 1107]
# Point 267: Left image coordinates: [ 515 1213], Right image coordinates: [620 757]
# Point 268: Left image coordinates: [ 548 1129], Right image coordinates: [ 628 1168]
# Point 269: Left image coordinates: [ 577 1267], Right image coordinates: [ 630 1054]
# Point 270: Left image coordinates: [474 339], Right image coordinates: [651 155]
# Point 271: Left image coordinates: [ 438 1043], Right image coordinates: [ 652 1254]
# Point 272: Left image coordinates: [335 830], Right image coordinates: [654 831]
# Point 273: Left image coordinates: [518 882], Right image coordinates: [ 660 1030]
# Point 274: Left image coordinates: [ 661 1125], Right image coordinates: [ 663 1122]
# Point 275: Left image coordinates: [630 300], Right image coordinates: [673 481]
# Point 276: Left image coordinates: [500 815], Right image coordinates: [ 674 1244]
# Point 277: Left image coordinates: [181 958], Right image coordinates: [ 680 1215]
# Point 278: Left image coordinates: [ 699 1025], Right image coordinates: [ 684 1125]
# Point 279: Left image coordinates: [ 675 1052], Right image coordinates: [ 685 1130]
# Point 280: Left image coordinates: [886 926], Right image coordinates: [693 787]
# Point 281: Left image coordinates: [306 850], Right image coordinates: [ 696 1217]
# Point 282: Left image coordinates: [562 662], Right image coordinates: [702 630]
# Point 283: Left image coordinates: [337 343], Right image coordinates: [702 193]
# Point 284: Left image coordinates: [419 853], Right image coordinates: [707 938]
# Point 285: Left image coordinates: [229 272], Right image coordinates: [709 238]
# Point 286: Left image coordinates: [ 228 1076], Right image coordinates: [ 720 1091]
# Point 287: Left image coordinates: [145 650], Right image coordinates: [722  35]
# Point 288: Left image coordinates: [790 949], Right image coordinates: [724 802]
# Point 289: Left image coordinates: [ 206 1115], Right image coordinates: [ 726 1141]
# Point 290: Left image coordinates: [431 781], Right image coordinates: [ 734 1036]
# Point 291: Left image coordinates: [145 650], Right image coordinates: [735  28]
# Point 292: Left image coordinates: [566 528], Right image coordinates: [737 219]
# Point 293: Left image coordinates: [ 210 1064], Right image coordinates: [749 959]
# Point 294: Left image coordinates: [898 267], Right image coordinates: [758 642]
# Point 295: Left image coordinates: [ 308 1086], Right image coordinates: [ 758 1030]
# Point 296: Left image coordinates: [669 975], Right image coordinates: [760 840]
# Point 297: Left image coordinates: [249 793], Right image coordinates: [761 240]
# Point 298: Left image coordinates: [279 816], Right image coordinates: [ 763 1105]
# Point 299: Left image coordinates: [459 765], Right image coordinates: [ 765 1165]
# Point 300: Left image coordinates: [871   6], Right image coordinates: [779   4]
# Point 301: Left image coordinates: [166 762], Right image coordinates: [780 951]
# Point 302: Left image coordinates: [ 598 1001], Right image coordinates: [784 905]
# Point 303: Left image coordinates: [853 846], Right image coordinates: [786 910]
# Point 304: Left image coordinates: [365 986], Right image coordinates: [ 786 1058]
# Point 305: Left image coordinates: [839 197], Right image coordinates: [789  86]
# Point 306: Left image coordinates: [446 411], Right image coordinates: [813 194]
# Point 307: Left image coordinates: [395 826], Right image coordinates: [ 826 1161]
# Point 308: Left image coordinates: [715 929], Right image coordinates: [851 952]
# Point 309: Left image coordinates: [726 547], Right image coordinates: [853  53]
# Point 310: Left image coordinates: [ 481 1109], Right image coordinates: [ 862 1054]
# Point 311: Left image coordinates: [ 410 1158], Right image coordinates: [868 962]
# Point 312: Left image coordinates: [192 945], Right image coordinates: [ 869 1049]
# Point 313: Left image coordinates: [495 744], Right image coordinates: [869 227]
# Point 314: Left image coordinates: [837  86], Right image coordinates: [873 164]
# Point 315: Left image coordinates: [193 960], Right image coordinates: [875 938]
# Point 316: Left image coordinates: [630 300], Right image coordinates: [879 551]
# Point 317: Left image coordinates: [630 300], Right image coordinates: [879 551]
# Point 318: Left image coordinates: [573 828], Right image coordinates: [893 379]
# Point 319: Left image coordinates: [589 551], Right image coordinates: [901 214]
# Point 320: Left image coordinates: [ 413 1079], Right image coordinates: [906 983]
# Point 321: Left image coordinates: [593 315], Right image coordinates: [912 157]
# Point 322: Left image coordinates: [ 535 1155], Right image coordinates: [ 932 1024]
# Point 323: Left image coordinates: [576 672], Right image coordinates: [941  79]
# Point 324: Left image coordinates: [749 931], Right image coordinates: [ 947 1145]

# %%
cv.imwrite('distances1.jpeg',img3)
# Out:
# True

# %%
cv.imwrite('distances2.jpeg',img4)
# Out:
# True
